# %% [markdown]
# **Q1. What is the difference between a function and a method in Python?**

# %% [markdown]
# Ans: 1. Function can be defined outside of a class. Method is defined inside a class. 2. Function can be called independently using its name, Method is called on an object.

# %% [markdown]
# **Q2. Explain the concept of function arguments and parameters in Python.**

# %% [markdown]
# Ans:
# Parameters - 1. These are the placeholders listed in a function's definition. 2. They define what inputs a function can accept.
#
# Arguments - 1. These are the actual values you pass into a function when you call it. 2. They are assigned to the parameters when the function executes.

# %% [markdown]
# **Q3. What are the different ways to define and call a function in Python?**

# %% [markdown]
# Ans: 1. Positional Arguments 2. Keyword Argument 3. Default Parameters etc.

# %% [markdown]
# **Q4. What is the purpose of the `return` statement in a Python function?**

# %% [markdown]
# Ans: 1. Send Back a Result to the Caller. 2. Exit the Function Early etc.

# %% [markdown]
# **Q5. What are iterators in Python and how do they differ from iterables?**

# %% [markdown]
# Ans: An iterable is any object you can loop over (e.g. lists, strings).
# An iterator is the object that actually does the iteration.

# %% [markdown]
# **Q6. Explain the concept of generators in Python and how they are defined.**

# %% [markdown]
# Ans: Generators in Python are a type of iterator that generate values on the fly, without storing them in memory

# %% [markdown]
# **Q7.What are the advantages of using generators over regular functions?**

# %% [markdown]
# Ans: Generators yield items one at a time, reducing memory usage, while regular functions return all items at once. Generators provide more concise, readable code for iteration. They are ideal for processing large or streaming data without loading everything into memory.

# %% [markdown]
# **Q8. What is a lambda function in Python and when is it typically used?**

# %% [markdown]
# Ans: A lambda function in Python is a small, anonymous function defined using the lambda keyword. It can have any number of arguments but only one expression.
#
# it is use for For simple, one-line functions.
# In higher-order functions like map(), filter(), and sorted().

# %% [markdown]
# **Q9.  Explain the purpose and usage of the `map()` function in Python.**

# %% [markdown]
# Ans: The map() function in Python applies a given function to each item in an iterable (like a list) and returns an iterator of the results.
# map(function, iterable).
#
# Usages:
# The result is an iterator that can be converted to a list, tuple, etc.

# %% [markdown]
# **Q10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**

# %% [markdown]
# Ans:
# MAP - 	Applies a function to each item.
# filter - 	Filters items based on a condition
# reduce - Reduces all items to a single value

# %% [markdown]
# Q.11 Write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]; **bold text**

# %% [markdown]
# Ans: unable to answer sorry.

# %% [markdown]
# ##Code

# %% [markdown]
# **Q1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.**

# %%
def sum_of_evens(numbers):
    return sum(num for num in numbers if num % 2 == 0)

my_list = [1, 2, 3, 4, 5, 6]

print(sum_of_evens(my_list))
# Out:
# 12

# %% [markdown]
# **Q2. Create a Python function that accepts a string and returns the reverse of that string.**

# %%
def reverse_string(s):
    return s[::-1]

text = "hello"
print(reverse_string(text))
# Out:
# olleh

# %% [markdown]
# Q3.  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_list(numbers):
    return [num ** 2 for num in numbers]

my_list = [1, 2, 3, 4]
print(square_list(my_list))
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# Q4.  Write a Python function that checks if a given number is prime or not from 1 to 200.

# %% [markdown]
# Q5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
